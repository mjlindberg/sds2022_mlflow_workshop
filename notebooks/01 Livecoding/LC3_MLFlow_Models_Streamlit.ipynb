# %%
#! pip install streamlit
import streamlit as st
# Out:
# 2022-06-19 22:02:36.388 INFO    numexpr.utils: NumExpr defaulting to 2 threads.

# %%
st.write("Hello")
# Out:
# 2022-06-19 22:02:38.147
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
# %%writefile app.py
import streamlit as st
PAGE_CONFIG = {"page_title":"StColab.io","page_icon":":smiley:","layout":"centered"}
st.beta_set_page_config(**PAGE_CONFIG)

def main():
	st.title("Awesome Streamlit for ML")
	st.subheader("How to run streamlit from colab")
	menu = ["Home","About"]
	choice = st.sidebar.selectbox('Menu',menu)
	if choice == 'Home':
		st.subheader("Streamlit From Colab")	
if __name__ == '__main__':
	main()
# Out:
# Overwriting app.py

# %%
# !ls
# Out:
# app.py	sample_data

# %%
# !streamlit run app.py &>/dev/null&

# %%
#!pip install pyngrok --quiet

# %%
from pyngrok import ngrok
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(port='8501')
public_url
# Out:
# 2022-06-19 22:02:51.521 Opening tunnel named: http-80-9af78110-d554-47a6-b501-52607add9e18
# 2022-06-19 22:02:51.648 t=2022-06-19T22:02:51+0000 lvl=info msg="no configuration paths supplied"
# 2022-06-19 22:02:51.656 t=2022-06-19T22:02:51+0000 lvl=info msg="using configuration at default config path" path=/root/.ngrok2/ngrok.yml
# 2022-06-19 22:02:51.662 t=2022-06-19T22:02:51+0000 lvl=info msg="open config file" path=/root/.ngrok2/ngrok.yml err=nil
# 2022-06-19 22:02:51.667 t=2022-06-19T22:02:51+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040
# 2022-06-19 22:02:51.848 t=2022-06-19T22:02:51+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# 2022-06-19 22:02:51.851 t=2022-06-19T22:02:51+0000 lvl=info msg="client session established" obj=csess id=e6d4cc96ab60
# 2022-06-19 22:02:51.863 t=2022-06-19T22:02:51+0000 lvl=info msg=start pg=/api/tunnels id=fb084941fe457bac
# 2022-06-19 22:02:51.866 t=2022-06-19T22:02:51+0000 lvl=info msg=end pg=/api/tunnels id=fb084941fe457bac status=200 dur=1.324018ms
# 2022-06-19 22:02:51.869 t=2022-06-19T22:02:51+0000 lvl=info msg=start pg=/api/tunnels id=1eaaae5936fe6037
# 2022-06-19 22:02:51.871 t=2022-06-19T22:02:51+0000 lvl=info msg=end pg=/api/tunnels id=1eaaae5936fe6037 status=200 dur=191.545µs
# 2022-06-19 22:02:51.873 t=2022-06-19T22:02:51+0000 lvl=info msg=start pg=/api/tunnels id=64dce4ccd8aa8814
# 2022-06-19 22:02:51.960 t=2022-06-19T22:02:51+0000 lvl=info msg="started tunnel" obj=tunnels name="http-80-9af78110-d554-47a6-b501-52607add9e18 (http)" addr=http://localhost:80 url=http://0d0c-34-74-155-217.ngrok.io
# 2022-06-19 22:02:51.967 t=2022-06-19T22:02:51+0000 lvl=info msg="started tunnel" obj=tunnels name=http-80-9af78110-d554-47a6-b501-52607add9e18 addr=http://localhost:80 url=https://0d0c-34-74-155-217.ngrok.io
# 2022-06-19 22:02:51.972 t=2022-06-19T22:02:51+0000 lvl=info msg=end pg=/api/tunnels id=64dce4ccd8aa8814 status=201 dur=91.082206ms
# 2022-06-19 22:02:51.988 t=2022-06-19T22:02:51+0000 lvl=info msg=start pg="/api/tunnels/http-80-9af78110-d554-47a6-b501-52607add9e18 (http)" id=48eb52130fcaf20d
# 2022-06-19 22:02:51.996 t=2022-06-19T22:02:51+0000 lvl=info msg=end pg="/api/tunnels/http-80-9af78110-d554-47a6-b501-52607add9e18 (http)" id=48eb52130fcaf20d status=200 dur=270.689µs
# <NgrokTunnel: "http://0d0c-34-74-155-217.ngrok.io" -> "http://localhost:80">
